# %%
import torch
from torch.utils.data import DataLoader
from transformers import BertTokenizer,BertModel
from tqdm import tqdm
import numpy as np
import pandas as pd

# %%
dfTest=pd.read_csv('Data/xhs/Glow/66594e45000000000c0193ca.csv')
dfTest.shape
dfTest.head(15)
# Out:
#                   comment_id    create_time ip_location  \
# 0   66599699000000000f0077fd  1717147289000         NaN
# 1   665a2484000000000e033b59  1717183621000         NaN
# 2   668f97a9000000000901572d  1720686505000         NaN
# 3   667847a8000000001500a540  1719158698000         NaN
# 4   6659fa1b000000000e03154d  1717172766000         NaN
# 5   665a9ed5000000000f005bc8  1717214933000         NaN
# 6   66688f90000000002101c5cc  1718128529000         NaN
# 7   66c726e0000000002603364a  1724327649000         NaN
# 8   66bd994f000000000f005fee  1723701585000         NaN
# 9   6694edac000000000401abc3  1721036206000         NaN
# 10  6659acf7000000000e032e5d  1717153016000         NaN
# 11  6659b1b9000000000e032775  1717154235000         NaN
# 12  6659b544000000000e033c6c  1717155141000         NaN
# 13  6659b580000000000f004d08  1717155201000         NaN
# 14  6659b61c000000000f004eb0  1717155357000         NaN
#
#                      note_id  \
# 0   66594e45000000000c0193ca
# ...
